# %%
from requests import get
url = 'https://www.imdb.com/search/title/?title_type=feature,tv_movie,documentary&release_date=2010-01-01,2018-12-31&sort=boxoffice_gross_us,desc&count=250'
response = get(url)
print(response.text[:500])
# Out:
# <!DOCTYPE html>
# <html
#     xmlns:og="http://ogp.me/ns#"
#     xmlns:fb="http://www.facebook.com/2008/fbml">
#     <head>
#
#         <meta charset="utf-8">
#         <meta http-equiv="X-UA-Compatible" content="IE=edge">
#
#     <meta name="apple-itunes-app" content="app-id=342792525, app-argument=imdb:///?src=mdot">
#
#
#
#         <script type="text/javascript">var IMDbTimer={starttime: new Date().getTime(),pt:'java'};</script>
#
# <script>
#     if (typeof uet == 'function') {
#       uet("bb", "LoadTitle"

# %%
import pandas as pd
from bs4 import BeautifulSoup
html_soup = BeautifulSoup(response.text, 'html.parser')
type(html_soup)
# Out:
# bs4.BeautifulSoup

# %%
movie_containers = html_soup.find_all('div', class_ = 'lister-item mode-advanced')
print(type(movie_containers))
print(len(movie_containers))
# Out:
# <class 'bs4.element.ResultSet'>
# 250

# %%
dlist = []
for container in movie_containers:
    d ={}
    
    d['movie'] = container.find('h3', class_="lister-item-header").text
    
    d['imdb_rating'] = container.find('div',class_ = "inline-block ratings-imdb-rating").text
    try:
        d["meta_score"] = container.find('div', class_= "inline-block ratings-metascore").text
    except:
        d['meta_score'] = None
        
    d['runtime'] = container.find('span', class_ = "runtime").text
    d['gross'] = container.find('p', class_ = "sort-num_votes-visible").text
    dlist.append(d)

# %%
dic_list = pd.DataFrame(dlist)
dic_list.head()
# Out:
#                                           movie imdb_rating  \
# 0  \n1.\nStar Wars: The Force Awakens\n(2015)\n   \n\n7.9\n
# 1                 \n2.\nBlack Panther\n(2018)\n   \n\n7.3\n
# 2        \n3.\nAvengers: Infinity War\n(2018)\n   \n\n8.5\n
# 3                \n4.\nJurassic World\n(2015)\n   \n\n7.0\n
# 4                  \n5.\nThe Avengers\n(2012)\n   \n\n8.0\n
#
#                                       meta_score  runtime  \
# 0  \n80        \n        Metascore\n              138 min
# 1  \n88        \n        Metascore\n              134 min
# 2  \n68        \n        Metascore\n              149 min
# 3  \n59        \n        Metascore\n              124 min
# 4  \n69        \n        Metascore\n              143 min
#
#                                        gross
# 0    \nVotes:\n835,619\n| Gross:\n$936.66M\n
# 1    \nVotes:\n579,369\n| Gross:\n$700.06M\n
# 2    \nVotes:\n770,546\n| Gross:\n$678.82M\n
# 3    \nVotes:\n561,929\n| Gross:\n$652.27M\n
# 4  \nVotes:\n1,229,293\n| Gross:\n$623.28M\n

# %%
dic_list = dic_list.replace(r'\n',  ' ', regex=True)

dic_list
# Out:
#                                         movie imdb_rating  \
# 0     1. Star Wars: The Force Awakens (2015)         7.9
# 1                    2. Black Panther (2018)         7.3
# 2           3. Avengers: Infinity War (2018)         8.5
# 3                   4. Jurassic World (2015)         7.0
# 4                     5. The Avengers (2012)         8.0
# ..                                        ...         ...
# 245                   246. The Upside (2017)         6.9
# 246                          247. Hop (2011)         5.4
# 247                  248. Baby Driver (2017)         7.6
# 248                         249. Epic (2013)         6.7
# 249                  250. Angry Birds (2016)         6.3
#
#                                      meta_score  runtime  \
# 0     80                 Metascore               138 min
# 1     88                 Metascore               134 min
# 2     68                 Metascore               149 min
# 3     59                 Metascore               124 min
# 4     69                 Metascore               143 min
# ..                                          ...      ...
# 245   46                 Metascore               126 min
# 246   41                 Metascore                95 min
# 247   86                 Metascore               113 min
# 248   52                 Metascore               102 min
# 249   43                 Metascore                97 min
#
#                                     gross
# 0       Votes: 835,619 | Gross: $936.66M
# 1       Votes: 579,369 | Gross: $700.06M
# 2       Votes: 770,546 | Gross: $678.82M
# 3       Votes: 561,929 | Gross: $652.27M
# 4     Votes: 1,229,293 | Gross: $623.28M
# ..                                    ...
# 245      Votes: 40,325 | Gross: $108.25M
# 246      Votes: 30,365 | Gross: $108.09M
# 247     Votes: 409,010 | Gross: $107.83M
# 248      Votes: 97,812 | Gross: $107.52M
# 249      Votes: 76,549 | Gross: $107.51M
#
# [250 rows x 5 columns]

# %%
dic_list.dropna(axis=0, how="any", thresh=None, subset=None, inplace=True)

# %%
movie_ratings = pd.DataFrame(dic_list)
print(movie_ratings.info())
movie_ratings.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 250 entries, 0 to 249
# Data columns (total 5 columns):
# movie          250 non-null object
# imdb_rating    250 non-null object
# meta_score     250 non-null object
# runtime        250 non-null object
# gross          250 non-null object
# dtypes: object(5)
# memory usage: 11.7+ KB
# None
#                                       movie imdb_rating  \
# 0   1. Star Wars: The Force Awakens (2015)         7.9
# 1                  2. Black Panther (2018)         7.3
# 2         3. Avengers: Infinity War (2018)         8.5
# 3                 4. Jurassic World (2015)         7.0
# 4                   5. The Avengers (2012)         8.0
# 5       6. Star Wars: The Last Jedi (2017)         7.0
# 6                  7. Incredibles 2 (2018)         7.6
# 7                      8. Rogue One (2016)         7.8
# 8       9. Beauty and the Beast (I) (2017)         7.1
# 9                  10. Finding Dory (2016)         7.3
#
#                                    meta_score  runtime  \
# 0   80                 Metascore               138 min
# 1   88                 Metascore               134 min
# 2   68                 Metascore               149 min
# 3   59                 Metascore               124 min
# 4   69                 Metascore               143 min
# 5   84                 Metascore               152 min
# 6   80                 Metascore               118 min
# 7   65                 Metascore               133 min
# 8   65                 Metascore               129 min
# 9   77                 Metascore                97 min
#
#                                   gross
# 0     Votes: 835,619 | Gross: $936.66M
# 1     Votes: 579,369 | Gross: $700.06M
# 2     Votes: 770,546 | Gross: $678.82M
# 3     Votes: 561,929 | Gross: $652.27M
# 4   Votes: 1,229,293 | Gross: $623.28M
# 5     Votes: 535,882 | Gross: $620.18M
# 6     Votes: 232,293 | Gross: $608.58M
# 7     Votes: 528,331 | Gross: $532.18M
# 8     Votes: 258,567 | Gross: $504.01M
# 9     Votes: 228,739 | Gross: $486.30M

# %%
movie_ratings = movie_ratings.dropna(axis=0, how="any", thresh=None, subset=None, inplace=False)

# %%
movie_ratings = movie_ratings.replace(r'\n',  ' ', regex=True)
movie_ratings
# Out:
#                                         movie imdb_rating  \
# 0     1. Star Wars: The Force Awakens (2015)         7.9
# 1                    2. Black Panther (2018)         7.3
# 2           3. Avengers: Infinity War (2018)         8.5
# 3                   4. Jurassic World (2015)         7.0
# 4                     5. The Avengers (2012)         8.0
# ..                                        ...         ...
# 245                   246. The Upside (2017)         6.9
# 246                          247. Hop (2011)         5.4
# 247                  248. Baby Driver (2017)         7.6
# 248                         249. Epic (2013)         6.7
# 249                  250. Angry Birds (2016)         6.3
#
#                                      meta_score  runtime  \
# 0     80                 Metascore               138 min
# 1     88                 Metascore               134 min
# 2     68                 Metascore               149 min
# 3     59                 Metascore               124 min
# 4     69                 Metascore               143 min
# ..                                          ...      ...
# 245   46                 Metascore               126 min
# 246   41                 Metascore                95 min
# 247   86                 Metascore               113 min
# 248   52                 Metascore               102 min
# 249   43                 Metascore                97 min
#
#                                     gross
# 0       Votes: 835,619 | Gross: $936.66M
# 1       Votes: 579,369 | Gross: $700.06M
# 2       Votes: 770,546 | Gross: $678.82M
# 3       Votes: 561,929 | Gross: $652.27M
# 4     Votes: 1,229,293 | Gross: $623.28M
# ..                                    ...
# 245      Votes: 40,325 | Gross: $108.25M
# 246      Votes: 30,365 | Gross: $108.09M
# 247     Votes: 409,010 | Gross: $107.83M
# 248      Votes: 97,812 | Gross: $107.52M
# 249      Votes: 76,549 | Gross: $107.51M
#
# [250 rows x 5 columns]

# %%
movie_ratings['meta_score'] = movie_ratings['meta_score'].str.replace("Metascore","")
movie_ratings.head()
# Out:
#                                       movie imdb_rating  \
# 0   1. Star Wars: The Force Awakens (2015)         7.9
# 1                  2. Black Panther (2018)         7.3
# 2         3. Avengers: Infinity War (2018)         8.5
# 3                 4. Jurassic World (2015)         7.0
# 4                   5. The Avengers (2012)         8.0
#
#                           meta_score  runtime  \
# 0   80                                138 min
# 1   88                                134 min
# 2   68                                149 min
# 3   59                                124 min
# 4   69                                143 min
#
#                                   gross
# 0     Votes: 835,619 | Gross: $936.66M
# 1     Votes: 579,369 | Gross: $700.06M
# 2     Votes: 770,546 | Gross: $678.82M
# 3     Votes: 561,929 | Gross: $652.27M
# 4   Votes: 1,229,293 | Gross: $623.28M

# %%
movie_ratings['runtime'] = movie_ratings['runtime'].str.replace("min","")

# %%
movie_ratings['runtime'] = movie_ratings['runtime'].astype(int)

# %%
movie_ratings['imdb_rating'] = movie_ratings['imdb_rating'].astype(float)
movie_ratings['meta_score'] = movie_ratings['meta_score'].astype(float)

# %%
print(type('imdb_rating'))
# Out:
# <class 'str'>

# %%
movie_ratings['n_imdb'] = movie_ratings['imdb_rating'] * 10
movie_ratings.head(3)
# Out:
#                                       movie  imdb_rating  meta_score  runtime  \
# 0   1. Star Wars: The Force Awakens (2015)           7.9        80.0      138
# 1                  2. Black Panther (2018)           7.3        88.0      134
# 2         3. Avengers: Infinity War (2018)           8.5        68.0      149
#
#                                 gross  n_imdb
# 0   Votes: 835,619 | Gross: $936.66M     79.0
# 1   Votes: 579,369 | Gross: $700.06M     73.0
# 2   Votes: 770,546 | Gross: $678.82M     85.0

# %%
movie_ratings.corr()
# Out:
#              imdb_rating  meta_score   runtime    n_imdb
# imdb_rating     1.000000    0.750389  0.332263  1.000000
# meta_score      0.750389    1.000000  0.209758  0.750389
# runtime         0.332263    0.209758  1.000000  0.332263
# n_imdb          1.000000    0.750389  0.332263  1.000000

# %%
movie_ratings['movie'] = movie_ratings['movie'].apply(lambda x: x.split(".")[1])

# %%
movie_ratings['movie'] = movie_ratings['movie'].apply(lambda x: x.split("(")[0])

# %%
movie_ratings.head()
# Out:
#                             movie  imdb_rating  meta_score  runtime  \
# 0   Star Wars: The Force Awakens           7.9        80.0      138
# 1                  Black Panther           7.3        88.0      134
# 2         Avengers: Infinity War           8.5        68.0      149
# 3                 Jurassic World           7.0        59.0      124
# 4                   The Avengers           8.0        69.0      143
#
#                                   gross  n_imdb
# 0     Votes: 835,619 | Gross: $936.66M     79.0
# 1     Votes: 579,369 | Gross: $700.06M     73.0
# 2     Votes: 770,546 | Gross: $678.82M     85.0
# 3     Votes: 561,929 | Gross: $652.27M     70.0
# 4   Votes: 1,229,293 | Gross: $623.28M     80.0

# %%
movie_ratings.corr()
# Out:
#              imdb_rating  meta_score   runtime    n_imdb
# imdb_rating     1.000000    0.750389  0.332263  1.000000
# meta_score      0.750389    1.000000  0.209758  0.750389
# runtime         0.332263    0.209758  1.000000  0.332263
# n_imdb          1.000000    0.750389  0.332263  1.000000

# %%
movie_ratings['gross'] = movie_ratings['gross'].apply(lambda x: x.split("$")[-1])

# %%
movie_ratings['gross']
# Out:
# 0      936.66M
# 1      700.06M
# 2      678.82M
# 3      652.27M
# 4      623.28M
#          ...
# 245    108.25M
# 246    108.09M
# 247    107.83M
# 248    107.52M
# 249    107.51M
# Name: gross, Length: 250, dtype: object

# %%
newdf = movie_ratings.loc[~movie_ratings['gross'].str.contains("Votes")]

# %%
newdf['gross'] = newdf['gross'].str.replace("M","")

# %%
newdf['gross'] = newdf['gross'].astype(float)

# %%
newdf
# Out:
#                               movie  imdb_rating  meta_score  runtime   gross  \
# 0     Star Wars: The Force Awakens           7.9        80.0      138  936.66
# 1                    Black Panther           7.3        88.0      134  700.06
# 2           Avengers: Infinity War           8.5        68.0      149  678.82
# 3                   Jurassic World           7.0        59.0      124  652.27
# 4                     The Avengers           8.0        69.0      143  623.28
# ..                              ...          ...         ...      ...     ...
# 245                     The Upside           6.9        46.0      126  108.25
# 246                            Hop           5.4        41.0       95  108.09
# 247                    Baby Driver           7.6        86.0      113  107.83
# 248                           Epic           6.7        52.0      102  107.52
# 249                    Angry Birds           6.3        43.0       97  107.51
#
#      n_imdb
# 0      79.0
# 1      73.0
# 2      85.0
# 3      70.0
# 4      80.0
# ..      ...
# 245    69.0
# 246    54.0
# 247    76.0
# 248    67.0
# 249    63.0
#
# [250 rows x 6 columns]

# %%
import pandas as pd

# %%
newdf.to_csv('cleandata/webscrape_top500grossfilms.csv')
