# %%
import json
import requests
import pandas as pd
import ast

# %%
with open("/Users/meganlyons/.secret/tmdbapi.json") as f:
    tmdb = json.load(f)

# %%
type(tmdb)
# Out:
# dict

# %%
business_endpoint = "https://api.themoviedb.org/3/genre/movie/list?"
params = {"language":"en-US"}
headers = {"api_key":f"Bearer {tmdb['api_key']}"}

# %%
r = requests.get(business_endpoint,params=params, headers=headers)

# %%
r
# Out:
# <Response [401]>

# %%
import json

def get_keys(path):
    with open(path) as f:
        return json.load(f)

# %%
keys = get_keys("/Users/meganlyons/.secret/tmdbapi.json")
api_key = keys['api_key']

# %%
r = requests.get(f"https://api.themoviedb.org/3/genre/movie/list?api_key={api_key}&language=en-US")

# %%
## This is a byte string
r.content
# Out:
# b'{"genres":[{"id":28,"name":"Action"},{"id":12,"name":"Adventure"},{"id":16,"name":"Animation"},{"id":35,"name":"Comedy"},{"id":80,"name":"Crime"},{"id":99,"name":"Documentary"},{"id":18,"name":"Drama"},{"id":10751,"name":"Family"},{"id":14,"name":"Fantasy"},{"id":36,"name":"History"},{"id":27,"name":"Horror"},{"id":10402,"name":"Music"},{"id":9648,"name":"Mystery"},{"id":10749,"name":"Romance"},{"id":878,"name":"Science Fiction"},{"id":10770,"name":"TV Movie"},{"id":53,"name":"Thriller"},{"id":10752,"name":"War"},{"id":37,"name":"Western"}]}'

# %%
# Converting to a Dictionary
json.loads(r.content)
# Out:
# {'genres': [{'id': 28, 'name': 'Action'},
#   {'id': 12, 'name': 'Adventure'},
#   {'id': 16, 'name': 'Animation'},
#   {'id': 35, 'name': 'Comedy'},
#   {'id': 80, 'name': 'Crime'},
#   {'id': 99, 'name': 'Documentary'},
#   {'id': 18, 'name': 'Drama'},
#   {'id': 10751, 'name': 'Family'},
#   {'id': 14, 'name': 'Fantasy'},
#   {'id': 36, 'name': 'History'},
#   {'id': 27, 'name': 'Horror'},
#   {'id': 10402, 'name': 'Music'},
#   {'id': 9648, 'name': 'Mystery'},
#   {'id': 10749, 'name': 'Romance'},
#   {'id': 878, 'name': 'Science Fiction'},
#   {'id': 10770, 'name': 'TV Movie'},
#   {'id': 53, 'name': 'Thriller'},
#   {'id': 10752, 'name': 'War'},
#   {'id': 37, 'name': 'Western'}]}

# %%
response = r.json()

# %%
response.keys()
# Out:
# dict_keys(['genres'])

# %%
d = pd.DataFrame(response['genres'])

# %%
genres = response['genres']

# %%
genres
# Out:
# [{'id': 28, 'name': 'Action'},
#  {'id': 12, 'name': 'Adventure'},
#  {'id': 16, 'name': 'Animation'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 80, 'name': 'Crime'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 10751, 'name': 'Family'},
#  {'id': 14, 'name': 'Fantasy'},
#  {'id': 36, 'name': 'History'},
#  {'id': 27, 'name': 'Horror'},
#  {'id': 10402, 'name': 'Music'},
#  {'id': 9648, 'name': 'Mystery'},
#  {'id': 10749, 'name': 'Romance'},
#  {'id': 878, 'name': 'Science Fiction'},
#  {'id': 10770, 'name': 'TV Movie'},
#  {'id': 53, 'name': 'Thriller'},
#  {'id': 10752, 'name': 'War'},
#  {'id': 37, 'name': 'Western'}]

# %%
genres[0]['id']
# Out:
# 28

# %%
sampleid = [12, 28, 878]

# %%
genres
def genrefunction(x):
    newlist = []
    for g in range(0,len(genres)):
        for i in range(0,len(x)): 
            if x[i] == genres[g]['id']:
                newlist.append(genres[g]['name'])
    return newlist

# %%
genrefunction(sampleid)
# Out:
# ['Action', 'Adventure', 'Science Fiction']

# %%
df = pd.read_csv('zippedData/tmdb.movies.csv',index_col = 0)

# %%
df.head()
# Out:
#              genre_ids     id original_language  \
# 0      [12, 14, 10751]  12444                en
# 1  [14, 12, 16, 10751]  10191                en
# 2        [12, 28, 878]  10138                en
# 3      [16, 35, 10751]    862                en
# 4        [28, 878, 12]  27205                en
#
#                                  original_title  popularity release_date  \
# 0  Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                      How to Train Your Dragon      28.734   2010-03-26
# 2                                    Iron Man 2      28.515   2010-05-07
# 3                                     Toy Story      28.005   1995-11-22
# 4                                     Inception      27.920   2010-07-16
#
#                                           title  vote_average  vote_count
# 0  Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# 1                      How to Train Your Dragon           7.7        7610
# 2                                    Iron Man 2           6.8       12368
# 3                                     Toy Story           7.9       10174
# 4                                     Inception           8.3       22186

# %%
df.loc[df['title'].str.contains("Star Wars")]
# Out:
#                       genre_ids      id original_language  \
# 62                [35, 878, 16]   51888                en
# 1174       [16, 878, 35, 10751]   79158                en
# 2960           [16, 10751, 878]   70608                en
# 4693                       [35]  515773                en
# 5636   [878, 16, 28, 10751, 35]  136406                en
# 8986                       [16]  379095                en
# 9379          [28, 12, 16, 878]  366224                en
# 10222             [28, 16, 878]  282315                en
# 11779         [12, 16, 28, 878]  287663                en
# 11874  [28, 16, 35, 10751, 878]  392216                en
# 12166           [16, 35, 10751]  369030                en
# 12588                      [99]  253150                en
# 12955                        []  465882                en
# 12998           [10751, 16, 35]  369036                en
# 13532                        []  465886                en
# 13671      [28, 16, 10751, 878]  408300                en
# 14172         [28, 12, 878, 14]  140607                en
# 14944         [12, 16, 878, 28]  337755                en
# 15181             [878, 28, 16]  332479                en
# 15759                      [99]  376798                en
# 16063         [14, 28, 878, 12]  357450                en
# 16211                      [99]  372909                en
# 16829                      [99]  372906                en
# 17385         [28, 12, 878, 14]  140607                en
# 17401             [28, 12, 878]  330459                en
# 18959         [16, 878, 28, 12]  418363                en
# 19181                      [28]  431575                en
# 19617                        []  411511                en
# 20624         [14, 12, 878, 28]  181808                en
# 20655             [28, 12, 878]  330459                en
# 22454         [28, 16, 878, 14]  479310                en
# 23390                     [878]  496039                en
# 23496                      [99]  515580                en
# 23496           6.0           1                      [99]
# 23831           7.0        8534         [14, 12, 878, 28]
# 23845           6.6        3838             [28, 12, 878]
# 25727           7.0           1                 [28, 878]
# 26325           8.0           2                      [99]
#
#                                               new_genres
# 62                  [Animation, Comedy, Science Fiction]
# 1174        [Animation, Comedy, Family, Science Fiction]
# 2960                [Animation, Family, Science Fiction]
# 4693                                            [Comedy]
# 5636   [Action, Animation, Comedy, Family, Science Fi...
# 8986                                         [Animation]
# 9379     [Action, Adventure, Animation, Science Fiction]
# 10222               [Action, Animation, Science Fiction]
# 11779    [Action, Adventure, Animation, Science Fiction]
# 11874  [Action, Animation, Comedy, Family, Science Fi...
# 12166                        [Animation, Comedy, Family]
# 12588                                      [Documentary]
# 12955                                                 []
# 12998                        [Animation, Comedy, Family]
# 13532                                                 []
# 13671       [Action, Animation, Family, Science Fiction]
# 14172      [Action, Adventure, Fantasy, Science Fiction]
# 14944    [Action, Adventure, Animation, Science Fiction]
# 15181               [Action, Animation, Science Fiction]
# 15759                                      [Documentary]
# 16063      [Action, Adventure, Fantasy, Science Fiction]
# 16211                                      [Documentary]
# 16829                                      [Documentary]
# 17385      [Action, Adventure, Fantasy, Science Fiction]
# 17401               [Action, Adventure, Science Fiction]
# 18959    [Action, Adventure, Animation, Science Fiction]
# 19181                                           [Action]
# 19617                                                 []
# 20624      [Action, Adventure, Fantasy, Science Fiction]
# 20655               [Action, Adventure, Science Fiction]
# 22454      [Action, Animation, Fantasy, Science Fiction]
# 23390                                  [Science Fiction]
# 23496                                      [Documentary]
# 23831      [Action, Adventure, Fantasy, Science Fiction]
# 23845               [Action, Adventure, Science Fiction]
# 25727                          [Action, Science Fiction]
# 26325                                      [Documentary]

# %%
# literal eval reads in a string and parses it into a python object
df['genre_id_list'] = df['genre_ids'].apply(ast.literal_eval)

# %%
df['new_genres'] = df['genre_id_list'].apply(genrefunction)

# %%
df.head()
# Out:
#              genre_ids     id original_language  \
# 0      [12, 14, 10751]  12444                en
# 1  [14, 12, 16, 10751]  10191                en
# 2        [12, 28, 878]  10138                en
# 3      [16, 35, 10751]    862                en
# 4        [28, 878, 12]  27205                en
#
#                                  original_title  popularity release_date  \
# 0  Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                      How to Train Your Dragon      28.734   2010-03-26
# 2                                    Iron Man 2      28.515   2010-05-07
# 3                                     Toy Story      28.005   1995-11-22
# 4                                     Inception      27.920   2010-07-16
#
#                                           title  vote_average  vote_count  \
# 0  Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# 1                      How to Train Your Dragon           7.7        7610
# 2                                    Iron Man 2           6.8       12368
# 3                                     Toy Story           7.9       10174
# 4                                     Inception           8.3       22186
#
#          genre_id_list                               new_genres
# 0      [12, 14, 10751]             [Adventure, Family, Fantasy]
# 1  [14, 12, 16, 10751]  [Adventure, Animation, Family, Fantasy]
# 2        [12, 28, 878]     [Action, Adventure, Science Fiction]
# 3      [16, 35, 10751]              [Animation, Comedy, Family]
# 4        [28, 878, 12]     [Action, Adventure, Science Fiction]

# %%
df.to_csv('cleandata/genredf.csv')

# %%
budgetdf = pd.read_csv('cleandata/movierevenue.csv', index_col = 0)
budgetdf.head()
# Out:
#    id release_date                                        movie  \
# 0   1   2009-12-18                                       Avatar
# 1   2   2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 2   3   2019-06-07                                 Dark Phoenix
# 3   4   2015-05-01                      Avengers: Age of Ultron
# 4   5   2017-12-15            Star Wars Ep. VIII: The Last Jedi
#
#    production_budget  domestic_gross  worldwide_gross  year_released  age  \
# 0          425000000       760507625       2776345279           2009   11
# 1          410600000       241063875       1045663875           2011    9
# 2          350000000        42762350        149762350           2019    1
# 3          330600000       459005868       1403013963           2015    5
# 4          317000000       620181382       1316721747           2017    3
#
#    decades     day  month    markup  profitmargin   netprofit
# 0        1  Friday     12  5.532577      0.846921  2351345279
# 1        0  Friday      5  1.546673      0.607331   635063875
# 2        0  Friday      6 -0.572108     -1.337036  -200237650
# 3        0  Friday      5  3.243841      0.764364  1072413963
# 4        0  Friday     12  3.153696      0.759251   999721747

# %% [markdown]
# # Creating a function to merge genres

# %%
def get_genres(movie_title):
    try:
        genres = df.loc[df['title']==movie_title,'new_genres'].values[0]
    except:
        genres = None
    return genres

# %%
get_genres(budgetdf['movie'][0])
# Out:
# ['Action', 'Adventure', 'Fantasy', 'Science Fiction']

# %%
budgetdf['genres'] = budgetdf['movie'].apply(get_genres)

# %%
budgetdf.head()
# Out:
#    id release_date                                        movie  \
# 0   1   2009-12-18                                       Avatar
# 1   2   2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 2   3   2019-06-07                                 Dark Phoenix
# 3   4   2015-05-01                      Avengers: Age of Ultron
# 4   5   2017-12-15            Star Wars Ep. VIII: The Last Jedi
#
#    production_budget  domestic_gross  worldwide_gross  year_released  age  \
# 0          425000000       760507625       2776345279           2009   11
# 1          410600000       241063875       1045663875           2011    9
# 2          350000000        42762350        149762350           2019    1
# 3          330600000       459005868       1403013963           2015    5
# 4          317000000       620181382       1316721747           2017    3
#
#    decades     day  month    markup  profitmargin   netprofit  \
# 0        1  Friday     12  5.532577      0.846921  2351345279
# 1        0  Friday      5  1.546673      0.607331   635063875
# 2        0  Friday      6 -0.572108     -1.337036  -200237650
# 3        0  Friday      5  3.243841      0.764364  1072413963
# 4        0  Friday     12  3.153696      0.759251   999721747
#
#                                           genres
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Action, Adventure, Fantasy]
# 2                                           None
# 3           [Action, Adventure, Science Fiction]
# 4                                           None

# %%
budgetdf.lof[budgetdf['movie'].str.contains('Star Wars')]

# %%
budgetdf.isna().sum()
# Out:
# id                      0
# release_date            0
# movie                   0
# production_budget       0
# domestic_gross          0
# worldwide_gross         0
# year_released           0
# age                     0
# decades                 0
# day                     0
# month                   0
# markup                  0
# profitmargin            0
# netprofit               0
# genres               3805
# dtype: int64

# %%
budgetdf.head()
# Out:
#    id release_date                                        movie  \
# 0   1   2009-12-18                                       Avatar
# 1   2   2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 2   3   2019-06-07                                 Dark Phoenix
# 3   4   2015-05-01                      Avengers: Age of Ultron
# 4   5   2017-12-15            Star Wars Ep. VIII: The Last Jedi
#
#    production_budget  domestic_gross  worldwide_gross  year_released  age  \
# 0          425000000       760507625       2776345279           2009   11
# 1          410600000       241063875       1045663875           2011    9
# 2          350000000        42762350        149762350           2019    1
# 3          330600000       459005868       1403013963           2015    5
# 4          317000000       620181382       1316721747           2017    3
#
#    decades     day  month    markup  profitmargin   netprofit  \
# 0        1  Friday     12  5.532577      0.846921  2351345279
# 1        0  Friday      5  1.546673      0.607331   635063875
# 2        0  Friday      6 -0.572108     -1.337036  -200237650
# 3        0  Friday      5  3.243841      0.764364  1072413963
# 4        0  Friday     12  3.153696      0.759251   999721747
#
#                                           genres
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Action, Adventure, Fantasy]
# 2                                           None
# 3           [Action, Adventure, Science Fiction]
# 4                                           None

# %%
budgetdf.loc[budgetdf['movie'].str.contains('Star Wars')]
# Out:
#       id release_date                                     movie  \
# 4      5   2017-12-15         Star Wars Ep. VIII: The Last Jedi
# 5      6   2015-12-18      Star Wars Ep. VII: The Force Awakens
# 11    12   2018-05-25                   Solo: A Star Wars Story
# 44    45   2016-12-16              Rogue One: A Star Wars Story
# 303    4   1999-05-19       Star Wars Ep. I: The Phantom Menace
# 304    5   2005-05-19    Star Wars Ep. III: Revenge of the Sith
# 305    6   2002-05-16    Star Wars Ep. II: Attack of the Clones
# 1783  84   1983-05-25      Star Wars Ep. VI: Return of the Jedi
# 2367  68   1980-05-21  Star Wars Ep. V: The Empire Strikes Back
# 3464  65   1977-05-25              Star Wars Ep. IV: A New Hope
# 3831  32   2008-08-15                 Star Wars: The Clone Wars
#
#       production_budget  domestic_gross  worldwide_gross  year_released  age  \
# 4             317000000       620181382       1316721747           2017    3
# 5             306000000       936662225       2053311220           2015    5
# 11            275000000       213767512        393151347           2018    2
# 44            200000000       532177324       1049102856           2016    4
# 303           115000000       474544677       1027044677           1999   21
# 304           115000000       380270577        848998877           2005   15
# 305           115000000       310676740        656695615           2002   18
# 1783           32500000       309205079        572705079           1983   37
# 2367           23000000       290271960        534161334           1980   40
# 3464           11000000       460998007        786598007           1977   43
# 3831            8500000        35161554         68695443           2008   12
#
#       decades        day  month     markup  profitmargin   netprofit  \
# 4           0     Friday     12   3.153696      0.759251   999721747
# 5           0     Friday     12   5.710167      0.850972  1747311220
# 11          0     Friday      5   0.429641      0.300524   118151347
# 44          0     Friday     12   4.245514      0.809361   849102856
# 303         2  Wednesday      5   7.930823      0.888028   912044677
# 304         1   Thursday      5   6.382599      0.864546   733998877
# 305         1   Thursday      5   4.710397      0.824881   541695615
# 1783        3  Wednesday      5  16.621695      0.943252   540205079
# 2367        4  Wednesday      5  22.224406      0.956942   511161334
# 3464        4  Wednesday      5  70.508910      0.986016   775598007
# 3831        1     Friday      8   7.081817      0.876265    60195443
#
#                                     genres
# 4                                     None
# 5                                     None
# 11    [Action, Adventure, Science Fiction]
# 44    [Action, Adventure, Science Fiction]
# 303                                   None
# 304                                   None
# 305                                   None
# 1783                                  None
# 2367                                  None
# 3464                                  None
# 3831                                  None

# %%
top500bygross = budgetdf.sort_values(by='worldwide_gross', ascending = False)[:500]

# %%
top500bygross.isna().sum()
# Out:
# id                     0
# release_date           0
# movie                  0
# production_budget      0
# domestic_gross         0
# worldwide_gross        0
# year_released          0
# age                    0
# decades                0
# day                    0
# month                  0
# markup                 0
# profitmargin           0
# netprofit              0
# genres               252
# dtype: int64

# %%
top500bygross.sort_values(by='genres', ascending = True)
# Out:
#       id release_date                     movie  production_budget  \
# 76    77   2012-06-22                     Brave          185000000
# 277   78   2018-07-13                Skyscraper          125000000
# 87    88   2016-07-01      The Legend of Tarzan          180000000
# 128   29   2014-11-07                Big Hero 6          165000000
# 210   11   2016-01-29           Kung Fu Panda 3          140000000
# ...   ..          ...                       ...                ...
# 2122  23   1998-12-11       Shakespeare in Love           26000000
# 2725  26   2000-07-07               Scary Movie           19000000
# 2490  91   1987-05-20      Beverly Hills Cop II           20000000
# 525   26   2002-06-14                Scooby-Doo           84000000
# 2495  96   1991-02-14  The Silence of the Lambs           20000000
#
#       domestic_gross  worldwide_gross  year_released  age  decades        day  \
# 76         237282182        554606532           2012    8        0     Friday
# 277         68420120        304115534           2018    2        0     Friday
# 87         126643061        348902025           2016    4        0     Friday
# 128        222527828        652127828           2014    6        0     Friday
# 210        143528619        517599142           2016    4        0     Friday
# ...              ...              ...            ...  ...      ...        ...
# 2122       100317794        279500000           1998   22        2     Friday
# 2725       157019771        277200000           2000   20        2     Friday
# 2490       153665036        276665036           1987   33        3  Wednesday
# 525        153294164        276294164           2002   18        1     Friday
# 2495       130726716        275726716           1991   29        2   Thursday
#
#       month     markup  profitmargin  netprofit  \
# 76        6   1.997873      0.666430  369606532
# 277       7   1.432924      0.588972  179115534
# 87        7   0.938345      0.484096  168902025
# 128      11   2.952290      0.746982  487127828
# 210       1   2.697137      0.729520  377599142
# ...     ...        ...           ...        ...
# 2122     12   9.750000      0.906977  253500000
# 2725      7  13.589474      0.931457  258200000
# 2490      5  12.833252      0.927710  256665036
# 525       6   2.289216      0.695976  192294164
# 2495      2  12.786336      0.927464  255726716
#
#                                               genres
# 76                                          [Action]
# 277                                         [Action]
# 87                               [Action, Adventure]
# 128   [Action, Adventure, Animation, Comedy, Family]
# 210   [Action, Adventure, Animation, Comedy, Family]
# ...                                              ...
# 2122                                            None
# 2725                                            None
# 2490                                            None
# 525                                             None
# 2495                                            None
#
# [500 rows x 15 columns]

# %%
budgetdf.to_csv('cleandata/Revenue_Budget_Genre.csv')
